# %% [markdown]
# <a href="https://colab.research.google.com/github/Biswadeep27/TF2_google_certificate/blob/draft_work_raj/Hello_TF2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Hello World of Neural Network
#
# In this example we will try to fit in a model for a simple problem of following linear regression.
#
# $$
# y = 2X -1
# $$

# %%
import tensorflow as tf
import numpy as nps
from tensorflow import keras

# %% [markdown]
# # Define and compile the neural Network
#
#
#
# *   we will create a neural netowork with 1 layer which has 1 neuron and the input shape to this is just 1 value.
# *   **Optimizer** : to guess the linear regression function : **Stochastic gradient descent**.
# *   **loss** : to calculate the deviation between predicted output and correct known output : **Mean squared Error**
# *   Based on how the loss function went, the Optimizer will try to minimize the loss at every next **Epoch**.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# # Providing the Data

# %%
xs = np.array([-1,0,1,2,3,4,5,6,7],dtype=float)
ys = np.array([-3,-1,1,3,5,7,9,11,13],dtype=float)

# %% [markdown]
# # Training the neural network

# %%
model.fit(xs,ys,epochs=500)
# Out:
# ss: 0.0099
# Epoch 257/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0097
# Epoch 258/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0096
# Epoch 259/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 260/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0093
# Epoch 261/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0091
# Epoch 262/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 263/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0088
# Epoch 264/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 265/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0085
# Epoch 266/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 267/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 268/500
# ...

# %%
print(model.predict([20.0]))
# Out:
# [[38.94056]]
